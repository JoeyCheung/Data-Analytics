# %% [markdown]
# ## HomeWork 2 EDA, Data Visualization and Linear Regression Model

# %% [markdown]
# # Due on 9/30/2019 mid-night

# %% [markdown]
# ## Late Policy: Take off 50% after one day, 80% after two days

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# ## Loading our MPG3 dataset

# %%
mpg = pd.read_csv("mpg3.csv")
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0  3504.0          12.0
# 1  15.0          8         350.0       165.0  3693.0          11.5
# 2  18.0          8         318.0       150.0  3436.0          11.0
# 3  16.0          8         304.0       150.0  3433.0          12.0
# 4  17.0          8         302.0       140.0  3449.0          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
mpg.shape
# Out:
# (405, 9)

# %% [markdown]
# # Question 1: Check to see if there are any missing values. Fix the missing values by imputing value from the mean. After fixing missing values, you should still have 405 rows

# %%
# Type your code here
mpg.isnull().any()
# Out:
# mpg              True
# cylinders       False
# displacement    False
# horsepower       True
# weight           True
# acceleration    False
# model_year      False
# origin          False
# name            False
# dtype: bool

# %%
var0 = 'horsepower'
var1 = 'weight'

# %%
sns.boxplot(y=mpg[var0])

# %%
oldval0 = mpg[var0]
oldval0.hist(bins=30)

# %%
newval0 = mpg[var0].fillna(mpg[var0].mean())
newval0.describe()
# Out:
# count    405.000000
# mean     105.593985
# std       42.002541
# min       46.000000
# 25%       76.000000
# 50%       95.000000
# 75%      125.000000
# max      450.000000
# Name: horsepower, dtype: float64

# %%
mpg[var0] = newval0
print(mpg.describe())
mpg.isnull().any()
# Out:
#               mpg   cylinders  displacement  horsepower        weight  \
# count  404.000000  405.000000    405.000000  405.000000    404.000000
# mean    23.645545    5.493827    194.504938  105.593985   3020.866337
# std      8.465607    1.847687    105.231828   42.002541   1282.513294
# min      9.000000    3.000000     68.000000   46.000000   1613.000000
# 25%     17.000000    4.000000    105.000000   76.000000   2227.500000
# 50%     23.000000    4.000000    151.000000   95.000000   2803.500000
# 75%     29.000000    8.000000    267.000000  125.000000   3614.750000
# max     90.000000   20.000000    455.000000  450.000000  22340.000000
#
#        acceleration  model_year
# count    405.000000  405.000000
# mean      15.521481   75.987654
# std        2.792380    3.746595
# min        8.000000   70.000000
# 25%       13.800000   73.000000
# 50%       15.500000   76.000000
# 75%       17.100000   79.000000
# max       24.800000   85.000000
# mpg              True
# cylinders       False
# displacement    False
# horsepower      False
# weight           True
# acceleration    False
# model_year      False
# origin          False
# name            False
# dtype: bool

# %%
newval1 = mpg[var1].fillna(mpg[var1].mean())
newval1.describe()
# Out:
# count      405.000000
# mean      3020.866337
# std       1280.925042
# min       1613.000000
# 25%       2228.000000
# 50%       2807.000000
# 75%       3613.000000
# max      22340.000000
# Name: weight, dtype: float64

# %%
mpg[var1] = newval1
print(mpg.describe())
mpg.isnull().any()
# Out:
#               mpg   cylinders  displacement  horsepower        weight  \
# count  404.000000  405.000000    405.000000  405.000000    405.000000
# mean    23.645545    5.493827    194.504938  105.593985   3020.866337
# std      8.465607    1.847687    105.231828   42.002541   1280.925042
# min      9.000000    3.000000     68.000000   46.000000   1613.000000
# 25%     17.000000    4.000000    105.000000   76.000000   2228.000000
# 50%     23.000000    4.000000    151.000000   95.000000   2807.000000
# 75%     29.000000    8.000000    267.000000  125.000000   3613.000000
# max     90.000000   20.000000    455.000000  450.000000  22340.000000
#
#        acceleration  model_year
# count    405.000000  405.000000
# mean      15.521481   75.987654
# std        2.792380    3.746595
# min        8.000000   70.000000
# 25%       13.800000   73.000000
# 50%       15.500000   76.000000
# 75%       17.100000   79.000000
# max       24.800000   85.000000
# mpg              True
# cylinders       False
# displacement    False
# horsepower      False
# weight          False
# acceleration    False
# model_year      False
# origin          False
# name            False
# dtype: bool

# %%
mpg['mpg'] = mpg['mpg'].fillna(mpg['mpg'].mean())
print(mpg.shape)
mpg.isnull().any()
# Out:
# (405, 9)
# mpg             False
# cylinders       False
# displacement    False
# horsepower      False
# weight          False
# acceleration    False
# model_year      False
# origin          False
# name            False
# dtype: bool

# %%
mpg.shape
# Out:
# (405, 9)

# %% [markdown]
# # Question 2 : Use Boxplot to see if there are any outliers on ALL of the numerical fields (Hint you should have 402 rows now after outliers removal)

# %% [markdown]
# **Type in your code here**

# %%
sns.boxplot(mpg['mpg'])
mpg = mpg[mpg['mpg'] < 45]

# %%
sns.boxplot(mpg['mpg'])

# %%
sns.boxplot(mpg['horsepower'])

# %%
sns.boxplot(mpg['weight'])
mpg = mpg[mpg['weight'] < 20000]

# %%
sns.boxplot(mpg['weight'])

# %%
sns.boxplot(mpg['cylinders'])

# %%
sns.boxplot(mpg['displacement'])

# %%
sns.boxplot(mpg['acceleration'])

# %%
sns.boxplot(mpg['model_year'])

# %%
mpg.shape
# Out:
# (402, 9)

# %% [markdown]
# # Question 3 : Remove any duplicates rows. Hint after removal, you should have 400 rows now

# %%
# Show number of rows before
print("Before duplicates removal: ", mpg.shape)

# Type your code here to remove duplicated rows
mpg = mpg.drop_duplicates()

# hint: Google how to remove duplicate rows in pandas dataframe and you will find the link
# https://pandas.pydata.org/pandas-docs/version/0.17/generated/pandas.DataFrame.drop_duplicates.html

# Show number of rows after
print("After duplicates removal: ", mpg.shape)
# Out:
# Before duplicates removal:  (402, 9)
# After duplicates removal:  (400, 9)

# %% [markdown]
# # Question 4: Create a pair plot

# %%
# Type your code here
sns.pairplot(data=mpg)

# %% [markdown]
# # Question 5: Create a FacetGrid of a scatter plot of mpg vs weight for different country

# %%
# Type your code here
g = sns.FacetGrid(mpg, col = 'origin')
g = (g.map(plt.scatter, "mpg", "weight").add_legend())

# %% [markdown]
# # Now Load the adult income dataset and do some EDA and answer the following questions based on the Adult income dataset

# %%
adult = pd.read_csv("adult.data.csv")
adult.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
# 2             0             0              40  United-States  <=50K
# 3             0             0              40  United-States  <=50K
# 4             0             0              40           Cuba  <=50K

# %%
adult.isnull().any()
# Out:
# age               False
# workclass         False
# fnlwgt            False
# education         False
# education-num     False
# marital-status    False
# occupation        False
# relationship      False
# race              False
# sex               False
# capital-gain      False
# capital-loss      False
# hours-per-week    False
# native-country    False
# salary            False
# dtype: bool

# %%
print(adult.shape)
adult.describe()
# Out:
# (32561, 15)
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %% [markdown]
# # Question 6 : Which two martial-status is most common

# %%
# Type your code here
adult['marital-status'].value_counts()
# Out:
# Married-civ-spouse       14976
# Never-married            10683
# Divorced                  4443
# Separated                 1025
# Widowed                    993
# Married-spouse-absent      418
# Married-AF-spouse           23
# Name: marital-status, dtype: int64

# %% [markdown]
# # Question 7: Plot the age distribution broken down by different martial-status using a FacetGrid

# %%
# Type your code here
g = sns.FacetGrid(adult, col = 'marital-status')
g = g.map(plt.hist, 'age', bins=30)

# %% [markdown]
# # Question 8: Create a Facet Grid for fnlwgt against age broken down by race and sex. You should have 10 sub-plots

# %%
# Type your code here
g = sns.FacetGrid(adult, col = 'race', row = 'sex')
g = (g.map(plt.scatter, "age", "fnlwgt").add_legend())

# %% [markdown]
# # Now Load the housing data and answer all the remaining questions based on the housing dataset

# %%
housing = pd.read_csv("USA_housing.csv")
housing.head()
# Out:
#         Income  HouseAge  NumberOfRooms  AreaNumberOfBedrooms   Population  \
# 0  79545.45857  5.682861       7.009188                  4.09  23086.80050
# 1  79248.64245  6.002900       6.730821                  3.09  40173.07217
# 2  61287.06718  5.865890       8.512727                  5.13  36882.15940
# 3  63345.24005  7.188236       5.586729                  3.26  34310.24283
# 4  59982.19723  5.040555       7.839388                  4.23  26354.10947
#
#           Price                                            Address
# 0  1.059034e+06  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  1.505891e+06  188 Johnson Views Suite 079\nLake Kathleen, CA...
# 2  1.058988e+06  9127 Elizabeth Stravenue\nDanieltown, WI 06482...
# 3  1.260617e+06                          USS Barnett\nFPO AP 44820
# 4  6.309435e+05                         USNS Raymond\nFPO AE 09386

# %%
# a scatter plot comparing num_children and num_pets
housing.plot(kind='scatter',x='Income',y='Price',color='blue')
plt.show()

# %%
housing.plot(kind='scatter', x = "HouseAge", y = "Price", color = "blue")

# %%
housing.plot(kind='scatter', x = "NumberOfRooms", y = "Price", color = "green")

# %% [markdown]
# # Question 9: Use a pair plot or individual scatter plots, pick ONE variable that best explains house price

# %%
# Type your answer (ie which variable affect the Price the most)
sns.pairplot(data = housing)
housing.corr()
# Out:
#                         Income  HouseAge  NumberOfRooms  AreaNumberOfBedrooms  \
# Income                1.000000 -0.002007      -0.011032              0.019788
# HouseAge             -0.002007  1.000000      -0.009428              0.006149
# NumberOfRooms        -0.011032 -0.009428       1.000000              0.462695
# AreaNumberOfBedrooms  0.019788  0.006149       0.462695              1.000000
# Population           -0.016234 -0.018743       0.002040             -0.022168
# Price                 0.639734  0.452543       0.335664              0.171071
#
#                       Population     Price
# Income                 -0.016234  0.639734
# HouseAge               -0.018743  0.452543
# NumberOfRooms           0.002040  0.335664
# AreaNumberOfBedrooms   -0.022168  0.171071
# Population              1.000000  0.408556
# Price                   0.408556  1.000000

# %% [markdown]
# *** Income ***

# %% [markdown]
# # Question 10:  Use that variable to build a one-variable Linear Regression model of the house price. Make sure you split the data between Training and Testing set first, Save 20% as your testing data

# %%
# Show your work here
# create a model
from sklearn.linear_model import LinearRegression

# %%
X = housing['Income'].values.reshape(-1,1)
Y = housing['Price'].values.reshape(-1,1)

# %%
model1 = LinearRegression()
model1.fit(X, Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
print(model1.intercept_)
print(model1.coef_)
# Out:
# [-221579.47822252]
# [[ 21.19548317]]

# %%
Y_pred = model1.predict(X)

# %%
Y_pred
# Out:
# array([[ 1464424.95032392],
#        [ 1458133.78924722],
#        [ 1077429.52286549],
#        ...,
#        [ 1122016.75902953],
#        [ 1219741.59376302],
#        [ 1166948.9559213 ]])

# %%
plt.scatter(X, Y,  color='gray')
plt.plot(X, Y_pred, color='red', linewidth=2)
plt.show()

# %%
from sklearn.model_selection import train_test_split 
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)

# %%
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
print(0.8 * housing.shape[0])
# Out:
# (4000, 1)
# (1000, 1)
# (4000, 1)
# (1000, 1)
# 4000.0

# %%
model2 = LinearRegression()
model2.fit(X_train, Y_train)
print(model2.intercept_)
print(model2.coef_)
# Out:
# [-224617.80110797]
# [[ 21.24368249]]

# %%
print(model1.intercept_)
print(model1.coef_)
# Out:
# [-221579.47822252]
# [[ 21.19548317]]

# %%
Y_pred = model2.predict(X_test)

# %%
plt.scatter(X_test, Y_test,  color='gray')
plt.scatter(X_test, Y_pred, color='red', linewidth=2)
plt.show()

# %%
# Show your R-square and RMSE

# %%
from sklearn import metrics

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(Y_test, Y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(Y_test, Y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(Y_test, Y_pred)))
print('R-squared:', metrics.r2_score(Y_test, Y_pred))
# Out:
# Mean Absolute Error: 219728.336018
# Mean Squared Error: 74084394120.8
# Root Mean Squared Error: 272184.485452
# R-squared: 0.400605980679

# %% [markdown]
# # Question 11: Now do a 10-fold Cross Validation of your model. Does your model pass cross validation?

# %%
# Show your work here

# %%
import random
for i in range(10):
    print(random.randint(1, 1000))
# Out:
# 922
# 432
# 208
# 37
# 619
# 686
# 514
# 948
# 896
# 140

# %%
for i in range(10):
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state = random.randint(1,1000))
    model = LinearRegression()
    model.fit(X_train, Y_train)
    Y_pred = model.predict(X_test)
    print('Trial {}, R-squared: {},  Slope: {}, Intercept: {},  '.format(i, metrics.r2_score(Y_test, Y_pred), \
                                                                      model.coef_, model.intercept_))
# Out:
# Trial 0, R-squared: 0.3871473485510524,  Slope: [[ 21.27396435]], Intercept: [-226702.45544835],
# Trial 1, R-squared: 0.3933427510940447,  Slope: [[ 21.22554043]], Intercept: [-224389.68018321],
# Trial 2, R-squared: 0.3749506069265922,  Slope: [[ 21.38070091]], Intercept: [-235916.60036199],
# Trial 3, R-squared: 0.400964344179611,  Slope: [[ 21.1660383]], Intercept: [-221901.73759086],
# Trial 4, R-squared: 0.4160297276843046,  Slope: [[ 21.18006747]], Intercept: [-222046.23105477],
# Trial 5, R-squared: 0.40390635673828157,  Slope: [[ 21.20806433]], Intercept: [-220829.0663438],
# Trial 6, R-squared: 0.39515725679572833,  Slope: [[ 21.22641336]], Intercept: [-225291.19412672],
# Trial 7, R-squared: 0.41749984978186117,  Slope: [[ 21.0537653]], Intercept: [-209822.11148707],
# Trial 8, R-squared: 0.4076720398571796,  Slope: [[ 21.30479549]], Intercept: [-232461.93082549],
# Trial 9, R-squared: 0.43296370976551135,  Slope: [[ 21.05630433]], Intercept: [-212112.12907833],

# %%
rdf.plot.bar(x='trial', y='Rsquare')

# %%
print(rdf['Rsquare'].mean())
# Out:
# 0.40889664118546526

# %%
# Question 12: Now pick ONE more variable in addition to the variable you choose from Question 9 and build a two-variables Linear Regression model of the house price. Make sure you split the data into training and testing set first

# %%
# Show your work here

# %%
X = housing[['Income','HouseAge']].values.reshape(-1, 2)
Y = housing['Price'].values.reshape(-1, 1)
 
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)
print(X_train.shape, X_test.shape)
print(Y_train.shape, Y_test.shape)
# Out:
# (4000, 2) (1000, 2)
# (4000, 1) (1000, 1)

# %%
model = LinearRegression()
model.fit(X_train, Y_train)
Y_pred = model.predict(X_test)
print(model.coef_)
print(model.intercept_)
# Out:
# [[  2.12204386e+01   1.60427782e+05]]
# [-1181216.65021219]

# %%
plt.scatter(Y_test, Y_pred, color='red', linewidth=2)
plt.show()

# %%
print('R-squared:', metrics.r2_score(Y_test, Y_pred))
# Out:
# R-squared: 0.611141617792

# %%
# Question 13: Do a 10-fold Cross Validation of your two-variable model. Does your model pass cross validation?

# %%
# Show your work here

# %%
rsquare = []
for i in range(10):
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state = random.randint(1,1000))
    model = LinearRegression()
    model.fit(X_train, Y_train)
    Y_pred = model.predict(X_test)
    rsquare.append(metrics.r2_score(Y_test, Y_pred))
    print('Trial {}, R-squared: {},  Slope: {}, Intercept: {},  '.format(i, metrics.r2_score(Y_test, Y_pred), \
                                                                      model.coef_, model.intercept_))

    
rdf = pd.DataFrame( {'trial': range(10), 'Rsquare': rsquare})
rdf.plot.bar(x='trial', y='Rsquare')
# Out:
# Trial 0, R-squared: 0.5869378549587476,  Slope: [[  2.13946080e+01   1.60646388e+05]], Intercept: [-1196655.93266427],
# Trial 1, R-squared: 0.6131162714243508,  Slope: [[  2.11614894e+01   1.60558107e+05]], Intercept: [-1178920.07188821],
# Trial 2, R-squared: 0.6296713589472341,  Slope: [[  2.12951180e+01   1.59524466e+05]], Intercept: [-1184507.8621118],
# Trial 3, R-squared: 0.596497932957723,  Slope: [[  2.13967971e+01   1.62938227e+05]], Intercept: [-1207308.81351077],
# Trial 4, R-squared: 0.6200026331318608,  Slope: [[  2.11615635e+01   1.60613114e+05]], Intercept: [-1178700.26676554],
# Trial 5, R-squared: 0.6289452003855711,  Slope: [[  2.12358767e+01   1.60749074e+05]], Intercept: [-1185799.62270734],
# Trial 6, R-squared: 0.5922970084508237,  Slope: [[  2.11886494e+01   1.61057293e+05]], Intercept: [-1184197.24103229],
# Trial 7, R-squared: 0.618845016600849,  Slope: [[  2.09141816e+01   1.58221673e+05]], Intercept: [-1148202.27033338],
# Trial 8, R-squared: 0.6176771077619342,  Slope: [[  2.09100847e+01   1.59577662e+05]], Intercept: [-1157029.60139703],
# Trial 9, R-squared: 0.6183125250762268,  Slope: [[  2.13070103e+01   1.59687559e+05]], Intercept: [-1183182.95457866],

# %%
print(rdf['Rsquare'].mean())
# Out:
# 0.6122302909695321
